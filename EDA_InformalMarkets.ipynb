# %% [markdown]
# # DATA DESCRIPTION
#
# ### This data includes features that could influence the factor, "LFPR (Labor Force Participation Rate) ", directly or indirectly.
# ### We consider the following features:
# ### 1) Innovation Index
# ### 2) Labor Freedom
# ### 3) Suicide Rate
# ### 4) Economic Globalization
# ### 5) Savings
# ### 6) Brain Drain
# ### 7) GDP Growth Rate
# ### 8) Population Change
# ### 9) HDI (Human Development Index)
# ### 10) Happiness Index

# %% [markdown]
# # AIM:
#
# ### To study the relationship between the above listed 10 factors and LFPR.

# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# # IMPORTING THE DATASET

# %%
df=pd.read_excel('/content/Data PDS org.xlsx')

# %% [markdown]
# ### LOOKING AT THE DATA

# %%
display(df)
# Out:
#    Year       LFPR  Innovation Index  Labor Freedom  Suicide Rate  \
# 0  2012  457753613               NaN            NaN          14.3
# 1  2013  461045398               NaN            NaN          13.7
# 2  2014  464104758              33.7            NaN          12.8
# 3  2015  466842711              31.7           49.0          12.3
# 4  2016  469541836              33.6           48.0          12.1
# 5  2017  471675710              35.5           42.0          12.0
# 6  2018  473422438              35.2           42.0          12.6
# 7  2019  482700285              36.6           42.0          12.7
# 8  2020  457779812              35.6           41.0           NaN
# 9  2021  471295529              36.4           41.0           NaN
#
#    Economic Globalization  Savings  Brain Drain  Cost of Living  \
# 0                   44.72    682.4          NaN           11.17
# 1                   43.63    682.7          NaN            9.13
# ...

# %%
df.describe()
# Out:
#              Year          LFPR  Innovation Index  Labor Freedom  \
# count    10.00000  1.000000e+01           8.00000       7.000000
# mean   2016.50000  4.676162e+08          34.78750      43.571429
# std       3.02765  7.782432e+06           1.66256       3.408672
# min    2012.00000  4.577536e+08          31.70000      41.000000
# 25%    2014.25000  4.618102e+08          33.67500      41.500000
# 50%    2016.50000  4.681923e+08          35.35000      42.000000
# 75%    2018.75000  4.715807e+08          35.80000      45.000000
# max    2021.00000  4.827003e+08          36.60000      49.000000
#
#        Suicide Rate  Economic Globalization     Savings  Brain Drain  \
# count      8.000000                8.000000    7.000000     7.000000
# mean      12.812500               42.377500  776.385714     5.885714
# std        0.800781                1.531356   81.309418     0.333809
# min       12.000000               40.140000  682.400000     5.500000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    10 non-null     int64
#  1   LFPR                    10 non-null     int64
#  2   Innovation Index        8 non-null      float64
#  3   Labor Freedom           7 non-null      float64
#  4   Suicide Rate            8 non-null      float64
#  5   Economic Globalization  8 non-null      float64
#  6   Savings                 7 non-null      float64
#  7   Brain Drain             7 non-null      float64
#  8   Cost of Living          10 non-null     float64
#  9   GDP growth rate         10 non-null     float64
#  10  Pop change              10 non-null     float64
#  11  HDI                     8 non-null      float64
#  12  Happiness Index         8 non-null      float64
# dtypes: float64(11), int64(2)
# memory usage: 1.1 KB

# %%
df[["LFPR"]] = df[["LFPR"]].astype("float")

# %%
df.dtypes
# Out:
# Year                        int64
# LFPR                      float64
# Innovation Index          float64
# Labor Freedom             float64
# Suicide Rate              float64
# Economic Globalization    float64
# Savings                   float64
# Brain Drain               float64
# Cost of Living            float64
# GDP growth rate           float64
# Pop change                float64
# HDI                       float64
# Happiness Index           float64
# dtype: object

# %%
df.head()
# Out:
#    Year         LFPR  Innovation Index  Labor Freedom  Suicide Rate  \
# 0  2012  457753613.0               NaN            NaN          14.3
# 1  2013  461045398.0               NaN            NaN          13.7
# 2  2014  464104758.0              33.7            NaN          12.8
# 3  2015  466842711.0              31.7           49.0          12.3
# 4  2016  469541836.0              33.6           48.0          12.1
#
#    Economic Globalization  Savings  Brain Drain  Cost of Living  \
# 0                   44.72    682.4          NaN           11.17
# 1                   43.63    682.7          NaN            9.13
# 2                   43.23    707.5          NaN            5.86
# 3                   40.73    840.7          5.5            6.32
# 4                   40.14    845.9          5.8            2.23
#
#    GDP growth rate  Pop change    HDI  Happiness Index
# 0           5.4564        1.34  0.597              NaN
# 1           6.3861        1.31  0.604            4.772
# ...

# %%
df.columns
# Out:
# Index(['Year', 'LFPR', 'Innovation Index', 'Labor Freedom', 'Suicide Rate',
#        'Economic Globalization', 'Savings', 'Brain Drain', 'Cost of Living',
#        'GDP growth rate', 'Pop change', 'HDI', 'Happiness Index'],
#       dtype='object')

# %%
Year=[2013,2014,2015,2016,2017,2018,2019,2020,2021]
LFPR=[461045398	,464104758,466842711,469541836,471675710,473422438,482700285,457779812,471295529]
plt.plot(Year, LFPR)
plt.title('TREND IN LFPR')
plt.xlabel('LFPR')
plt.ylabel('YEAR')
# Out:
# Text(0, 0.5, 'YEAR')

# %% [markdown]
# # DATA CLEANSING

# %% [markdown]
# ### FINDING DUPLICATES

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### FIND NULL VALUES

# %%
df.isnull().sum()
# Out:
# Year                      0
# LFPR                      0
# Innovation Index          2
# Labor Freedom             3
# Suicide Rate              2
# Economic Globalization    2
# Savings                   3
# Brain Drain               3
# Cost of Living            0
# GDP growth rate           0
# Pop change                0
# HDI                       2
# Happiness Index           2
# dtype: int64

# %% [markdown]
# ### HANDLING THE MISSING VALUES

# %%
df['Innovation Index']=df['Innovation Index'].fillna(int(df['Innovation Index'].mean()))
df['Labor Freedom']=df['Labor Freedom'].fillna(int(df['Labor Freedom'].mean()))
df['Suicide Rate']=df['Suicide Rate'].fillna(int(df['Suicide Rate'].mean()))
df['Economic Globalization']=df['Economic Globalization'].fillna(int(df['Economic Globalization'].mean()))
df['Savings']=df['Savings'].fillna(int(df['Savings'].mean()))
df['Brain Drain']=df['Brain Drain'].fillna(int(df['Brain Drain'].mean()))
df['HDI']=df['HDI'].fillna(int(df['HDI'].mean()))
df['Happiness Index']=df['Happiness Index'].fillna(int(df['Happiness Index'].mean()))

# %% [markdown]
# ### REPRINTING THE MODIFIED DATA

# %%
print(df)
# Out:
#    Year         LFPR  Innovation Index  Labor Freedom  Suicide Rate  \
# 0  2012  457753613.0              34.0           43.0          14.3
# 1  2013  461045398.0              34.0           43.0          13.7
# 2  2014  464104758.0              33.7           43.0          12.8
# 3  2015  466842711.0              31.7           49.0          12.3
# 4  2016  469541836.0              33.6           48.0          12.1
# 5  2017  471675710.0              35.5           42.0          12.0
# 6  2018  473422438.0              35.2           42.0          12.6
# 7  2019  482700285.0              36.6           42.0          12.7
# 8  2020  457779812.0              35.6           41.0          12.0
# 9  2021  471295529.0              36.4           41.0          12.0
#
#    Economic Globalization  Savings  Brain Drain  Cost of Living  \
# 0                   44.72    682.4          5.0           11.17
# 1                   43.63    682.7          5.0            9.13
# ...

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %% [markdown]
# ### CHECKING FOR OUTLIERS

# %% [markdown]
# ### In the boxplots below, the length of the box is IQR, and the minimum and maximum values are represented by the whiskers. The whiskers are generally extended into 1.5 x IQR distance on either side of the box. Therefore, all data points outside these 1.5 x IQR values are flagged as outliers.

# %% [markdown]
# ### BOXPLOT FOR INNOVATION INDEX

# %%
plt.boxplot(df['Innovation Index'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f277ce1a3d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f277ce1ae50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f277ce10390>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f277ce20950>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f277ce20e90>],
#  'means': []}

# %% [markdown]
# ### BOXPLOT FOR LABOR FREEDOM

# %%
plt.boxplot(df['Labor Freedom'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f277ce00b10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f277ce045d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f277ce00550>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f277cd8b0d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f277cd8b610>],
#  'means': []}

# %% [markdown]
# ### FINDING THE POSITION OF THE OUTLIER AND REPLACING IT

# %%
#Position of the Outlier
print(np.where(df['Labor Freedom']>47))
print(np.where(df['Labor Freedom']>48))

#replacing
import statistics
a=statistics.median(df['Labor Freedom'])
df['Labor Freedom']=df['Labor Freedom']. replace(49.0, a)
df['Labor Freedom']=df['Labor Freedom']. replace(48.0, a)
# Out:
# (array([3, 4]),)
# (array([3]),)

# %%
plt.boxplot(df['Labor Freedom'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f277cd84990>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f277cd09450>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f277cd84410>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f277cd09f10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f277cd12490>],
#  'means': []}

# %% [markdown]
# ### BOXPLOT FOR SUICIDE RATE

# %%
plt.boxplot(df['Suicide Rate'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f277ccfc910>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f277cd023d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f277ccfc390>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f277cd02e90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f277cc8a410>],
#  'means': []}

# %% [markdown]
# ### FINDING THE OUTLIER AND REPLACING IT

# %%
# Position of the Outlier
print(np.where(df['Suicide Rate']>13.5))
# Out:
# (array([0, 1]),)

# %%
import statistics
a=statistics.median(df['Suicide Rate'])
df['Suicide Rate']=df['Suicide Rate']. replace(14.3, a)
display(df['Suicide Rate'])
plt.boxplot(df['Suicide Rate'])
# Out:
# 0    12.45
# 1    13.70
# 2    12.80
# 3    12.30
# 4    12.10
# 5    12.00
# 6    12.60
# 7    12.70
# 8    12.00
# 9    12.00
# Name: Suicide Rate, dtype: float64
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f277cc69450>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f277cc69ed0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f277cc63e50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f277cc709d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f277cc70f10>],
#  'means': []}

# %% [markdown]
# ### FINDING THE OUTLIER AND REPLACING IT: 2

# %%
a=statistics.median(df['Suicide Rate'])
df['Suicide Rate']=df['Suicide Rate']. replace(13.7, a)
plt.boxplot(df['Suicide Rate'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f277cbdb910>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f277cbe23d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f277cbdb390>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f277cbe2e90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f277cbeb410>],
#  'means': []}

# %% [markdown]
# ### BOXPLOT FOR ECONOMIC GLOBALIZATION

# %%
plt.boxplot(df['Economic Globalization'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f277cb56390>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f277cb56e10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f277cb4fdd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f277cb5e910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f277cb5ee50>],
#  'means': []}

# %% [markdown]
# ### BOXPLOT FOR SAVINGS

# %%
plt.boxplot(df['Savings'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f277cb42310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f277cad5210>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f277cb42150>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f277cad5cd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f277cadb250>],
#  'means': []}

# %% [markdown]
# ### BOXPLOT FOR BRAIN DRAIN

# %%
plt.boxplot(df['Brain Drain'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f277cd4eb50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f277cd58510>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f277d2e5b50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f277ce10710>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f277d299c50>],
#  'means': []}

# %% [markdown]
# ### BOXPLOT: COST OF LIVING

# %%
plt.boxplot(df['Cost of Living'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f277cc24b90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f277cb78890>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f277caf2c10>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f277ccb2d50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f277cb91e50>],
#  'means': []}

# %% [markdown]
# ### BOXPLOT: GDP GROWTH RATE

# %%
plt.boxplot(df['GDP growth rate'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f277c9f78d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f277c9fc390>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f277c9f7350>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f277c9fce50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f277ca063d0>],
#  'means': []}

# %% [markdown]
# ### FINDING THE OUTLIER AND REPLACING IT

# %%
a=statistics.median(df['GDP growth rate'])
df['GDP growth rate']=df['GDP growth rate']. replace(-6.5961, a)
plt.boxplot(df['GDP growth rate'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f277c9741d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f277c974c50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f277c96cbd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f277c97e750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f277c97ec90>],
#  'means': []}

# %%
a=statistics.median(df['GDP growth rate'])
df['GDP growth rate']=df['GDP growth rate']. replace( 3.7379, a)
plt.boxplot(df['GDP growth rate'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f277c8dc990>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f277c8e1450>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f277c8dc410>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f277c8e1f10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f277c8e9490>],
#  'means': []}

# %% [markdown]
# ### BOXPLOT: HDI

# %%
plt.boxplot(df['HDI'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f277c850990>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f277c856450>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f277c8503d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f277c856f10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f277c85d490>],
#  'means': []}

# %% [markdown]
# ### FINDING THE OUTLIER AND REPLACING IT

# %%
a=statistics.median(df['HDI'])
df['HDI']=df['HDI']. replace(0.0, a)
plt.boxplot(df['HDI'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f277c83fe90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f277c844950>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f277c83f910>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f277c7cb450>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f277c7cb990>],
#  'means': []}

# %% [markdown]
# ### BOXPLOT: HAPPINESS INDEX

# %%
plt.boxplot(df['Happiness Index'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f277c7a8c50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f277c7b2710>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f277c7a86d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f277c7b9210>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f277c7b9750>],
#  'means': []}

# %% [markdown]
# ### BOXPLOT: POPULATION CHANGE

# %%
plt.boxplot(df['Pop change'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f277c71dc90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f277c722750>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f277c71d710>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f277c72a250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f277c72a790>],
#  'means': []}

# %% [markdown]
# ### DISPLAYING THE DATA THAT HAS THE OUTLIERS REMOVED

# %%
display(df)
# Out:
#    Year         LFPR  Innovation Index  Labor Freedom  Suicide Rate  \
# 0  2012  457753613.0              34.0           43.0        12.450
# 1  2013  461045398.0              34.0           43.0        12.375
# 2  2014  464104758.0              33.7           43.0        12.800
# 3  2015  466842711.0              31.7           42.5        12.300
# 4  2016  469541836.0              33.6           42.5        12.100
# 5  2017  471675710.0              35.5           42.0        12.000
# 6  2018  473422438.0              35.2           42.0        12.600
# 7  2019  482700285.0              36.6           42.0        12.700
# 8  2020  457779812.0              35.6           41.0        12.000
# 9  2021  471295529.0              36.4           41.0        12.000
#
#    Economic Globalization  Savings  Brain Drain  Cost of Living  \
# 0                   44.72    682.4          5.0           11.17
# 1                   43.63    682.7          5.0            9.13
# ...

# %% [markdown]
# # CORRELATION MATRIX

# %% [markdown]
# ### A table which displays the correlation coefficients for different variables. The matrix depicts the correlation between all the possible pairs of values in a table. It is a powerful tool to summarize a large dataset and to identify and visualize patterns in the given data

# %%
corrmatrix=df.corr()
plt.subplots(figsize=(10,4))
sns.heatmap(corrmatrix,vmin=-2,vmax=1,annot=True,linewidth=0.2,cmap='YlGnBu')

# %% [markdown]
# ### HIGHLY CORRELATED PAIRS ARE (+0.7 to +0.9 and -0.7 to -0.9):
#
# ### 1) Labor Freedom - Population Change (0.95)
# ### 2) Economic Globalization - Savings (-0.85)
# ### 3) Economic Globalization - Cost of Living (0.7)
# ### 4) Savings - Brain Drain (0.78)
# ### 5) Savings - Cost of Living (-0.71)
# ### 6) Savings - HDI (0.78)
# ### 7) Brain Drain - HDI (0.92)
# ### 8) GDP growth rate - Economic Globalization (-0.71)

# %%
plt.plot(df['Year'],df['Economic Globalization'],color="olive")
plt.plot(df['Year'],df['Cost of Living'],color="green",marker="o")
plt.xlabel('YEAR')
plt.ylabel('VALUES')
plt.title('ECONOMIC GLOBALIZATION AND COST OF LIVING OVER THE YEARS')
# Out:
# Text(0.5, 1.0, 'ECONOMIC GLOBALIZATION AND COST OF LIVING OVER THE YEARS')

# %%
plt.plot(df['Year'],df['Cost of Living'],color="blue")
plt.plot(df['Year'],df['Brain Drain'],color="red",marker="o")
plt.xlabel('YEAR')
plt.ylabel('VALUES')
plt.title('COST OF LIVING AND BRAIN DRAIN OVER THE YEARS')
plt.show()

# %%
plt.plot(df['Year'],df['Brain Drain'],color="purple")
plt.plot(df['Year'],df['HDI'],color="red",marker="o")
plt.xlabel('YEAR')
plt.ylabel('VALUES')
plt.title(' BRAIN DRAIN AND HDI OVER THE YEARS')
plt.show()

# %%
plt.plot(df['Year'],df['Economic Globalization'],color="yellow")
plt.plot(df['Year'],df['GDP growth rate'],color="green",marker="o")

# %%
plt.plot(df['Year'],df['Pop change'],color="orange")
plt.plot(df['Year'],df['Labor Freedom'],color="crimson",marker="o")
plt.show()

# %%
import matplotlib.pyplot as plt

df3=df.drop(['Year','LFPR','Savings'],axis=1)
df3.plot(ylim=(-25,100),figsize=(10,10),linewidth=2.5)
plt.legend(loc=1)

# %% [markdown]
# # VERIFYING THE FEATURES

# %% [markdown]
# ### VERIFY SAVINGS

# %%
sns.lmplot(x="Savings", y="Cost of Living", data=df)

# %%
sns.lmplot(x="HDI", y="Savings", data=df)

# %%
sns.lmplot(x="Brain Drain", y="Savings", data=df)

# %% [markdown]
# ### We will omit Savings as it is highly correlated to Cost of Living, HDI, Brain Drain

# %% [markdown]
# ### VERIFYING COST OF LIVING

# %%
sns.lmplot(x="Economic Globalization", y="Cost of Living", data=df)

# %% [markdown]
# ### Omiiting Cost of Living as it highly related to Economic Globalization

# %% [markdown]
# ### ECONOMIC GLOBALIZATION

# %%
sns.lmplot(x="Savings", y="Economic Globalization", data=df)

# %%
sns.lmplot(x="HDI", y="Economic Globalization", data=df)

# %% [markdown]
# ### POPULATION CHANGE AND LABOR FREEDOM

# %%
sns.lmplot(x="Pop change", y="Labor Freedom", data=df)

# %% [markdown]
# ### Population Change and Labor Freedom correlate only with each other and no other variable. Therefore, we can keep any one variable and remove the other.
# ### We shall make a choice to remove Population Change and keep Labor Freedom

# %% [markdown]
# ### CHECKING FOR BRAIN DRAIN

# %%
sns.lmplot(x="Brain Drain", y="HDI", data=df)

# %%
sns.lmplot(x="HDI", y="Happiness Index", data=df)

# %%
sns.lmplot(x="HDI", y="Brain Drain", data=df)

# %%
sns.lmplot(x="HDI", y="Pop change", data=df)

# %% [markdown]
# ### We shall keep Brain Drain as HDI is correlated with many other variables

# %% [markdown]
# ### VERIFY FOR GDP GROWTH RATE

# %%
sns.lmplot(x="GDP growth rate", y="Economic Globalization", data=df)

# %%
new_df=df.drop(['Pop change','Savings', 'HDI', 'Cost of Living','GDP growth rate'],axis=1)

# %%
new_df=new_df.set_index(['Year'])

# %%
import matplotlib.pyplot as plt

new_df.plot(ylim=(-25,100),figsize=(10,10),linewidth=2.5)
plt.legend(loc=1)

# %%
plt.plot('Labor Freedom',data=new_df,color="mediumaquamarine")
plt.xlabel('YEAR')
plt.ylabel('LABOR FREEDOM')
plt.title('TREND IN LABOR FREEDOM')
# Out:
# Text(0.5, 1.0, 'TREND IN LABOR FREEDOM')

# %% [markdown]
# Reduction in the formation and programming of Trade Unions could be a reason to explain the step by step decline of Labor Freedom

# %%
plt.plot('Happiness Index',data=new_df,color="crimson")
plt.xlabel('YEAR')
plt.ylabel('HAPPINESS INDEX')
plt.title('TREND IN HAPPINESS INDEX')
# Out:
# Text(0.5, 1.0, 'TREND IN HAPPINESS INDEX')

# %% [markdown]
# Failed to find an explanation to the dip in suicide rates since 2013 and the rise from 2014 to another decline to 2020.
#
# The slow rise in Happiness Index could be due to how grateful people became after the Pandemic
#
# (https://www.verywellmind.com/learning-to-be-happy-again-post-pandemic-5181160)

# %%
plt.plot('Innovation Index',data=new_df,color="darkgreen")
plt.xlabel('YEAR')
plt.ylabel('INNOVATION INDEX')
plt.title('TREND IN INNOVATION INDEX')
# Out:
# Text(0.5, 1.0, 'TREND IN INNOVATION INDEX')

# %% [markdown]
# Sharp rise from 2015?
#
# Possibly due to PM's Introduction of Mudra Scheme in April, 2015.

# %%
plt.plot('Suicide Rate',data=new_df,color="navy")
plt.xlabel('YEAR')
plt.ylabel('SUICIDE RATE')
plt.title('TREND IN SUICIDE RATE')
# Out:
# Text(0.5, 1.0, 'TREND IN SUICIDE RATE')

# %% [markdown]
# Failed to find an explanation to the dip in suicide rates since 2014 and the rise from 2017 to another decline from late 2019

# %%
plt.plot('Economic Globalization',data=new_df,color="crimson")
plt.xlabel('YEAR')
plt.ylabel('ECONOMIC GLOBALIZATION')
plt.title('TREND IN ECONOMIC GLOBALIZATION')
# Out:
# Text(0.5, 1.0, 'TREND IN ECONOMIC GLOBALIZATION')

# %% [markdown]
# Dip in 2016, why?
#
# By early 2016, global stock markets were falling hard. Negative economic reports from China caused panic selling. Interest rates fell sharply, and there were widespread warnings of deflation and depression. Global central banks stepped in with a coordinated increase in the global money supply.

# %%
plt.plot('Brain Drain',data=new_df,color="crimson")
plt.xlabel('YEAR')
plt.ylabel('BRAIN DRAIN')
plt.title('TREND IN BRAIN DRAIN')
# Out:
# Text(0.5, 1.0, 'TREND IN BRAIN DRAIN')

# %% [markdown]
# Migration of Indian Workers to Gulf dropped by 62 Per Cent Over Five Years (considering 2022 as well) because emigration clearance dropped by 21 Per Cent in 11 Months as of 2018 and it still goes on.

# %%
sns.set_style('whitegrid')

fig = plt.gcf()
fig.set_size_inches(16, 10)
sns.kdeplot(data=df.LFPR, shade=True, color= "blue", legend= None)

plt.xlabel('LFPR')
plt.title('DISTRIBUTION OF LFPR')
# Out:
# Text(0.5, 1.0, 'DISTRIBUTION OF LFPR')

# %% [markdown]
# # DATA TRANSFORMATION

# %% [markdown]
# ### Normalization is a technique often applied as part of data preparation for machine learning. The goal of normalization is to change the values of numeric columns in the dataset to use a common scale, without distorting differences in the ranges of values or losing information. Applying the normalization formula helps in expressing the data points as values from zero to one, with the smallest data point having a normalized value of zero and the largest data point have a normalized value of one. All the other data points have decimal values between these two, in proportion to where that data point is within the range of the data set.

# %%
# !pip install sklearn
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2344 sha256=c71139f9db351b003b756d4c595a9eabb474a97a5a30486e67948cb91dd31028
#   Stored in directory: /root/.cache/pip/wheels/42/56/cc/4a8bf86613aafd5b7f1b310477667c1fca5c51c3ae4124a003
# Successfully built sklearn
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
new_df.hist(figsize=(20,15))
plt.show()

# %%
from sklearn import preprocessing

# %%
d = preprocessing.normalize(new_df)
scaled_df = pd.DataFrame(d, columns=new_df.columns)
scaled_df.head()
# Out:
#    LFPR  Innovation Index  Labor Freedom  Suicide Rate  \
# 0   1.0      7.427577e-08   9.393700e-08  2.719804e-08
# 1   1.0      7.374545e-08   9.326630e-08  2.684117e-08
# 2   1.0      7.261292e-08   9.265150e-08  2.757998e-08
# 3   1.0      6.790296e-08   9.103709e-08  2.634720e-08
# 4   1.0      7.155912e-08   9.051377e-08  2.576980e-08
#
#    Economic Globalization   Brain Drain  Happiness Index
# 0            9.769448e-08  1.092291e-08     8.738325e-09
# 1            9.463276e-08  1.084492e-08     1.035039e-08
# 2            9.314707e-08  1.077343e-08     8.618744e-09
# 3            8.724566e-08  1.178127e-08     9.778454e-09
# 4            8.548759e-08  1.235247e-08     9.379356e-09

# %%
scaled_df.hist(figsize=(20,15))
plt.show()

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# From the above exploratory analysis:
#
# 1) We filtered the data out from 10 features to have 6 Independent variables that are dependent on LFPR. Thus, solving the possible issue of multicollinearity when formulating a regression model.
#
# 2) The possible relation between the variables could be discovered
#
# The government and the regulations can affect the LFPR in India and henceforth effective policies must be framed to help boost Indian LFPR
